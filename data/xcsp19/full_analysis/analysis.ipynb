# %%
from metrics.wallet import *

# %%
analysis = import_analysis_from_file('analysis.csv')

# %%
df = analysis.data_frame

print(df.iloc[:,0:3].head().to_markdown())
# Out:
# |    | input                                                    | experiment_ware         |   cpu_time |
# |---:|:---------------------------------------------------------|:------------------------|-----------:|
# |  0 | XCSP17/AllInterval/AllInterval-m1-s1/AllInterval-035.xml | BTD 19.07.01            |   0.031203 |
# |  1 | XCSP17/AllInterval/AllInterval-m1-s1/AllInterval-035.xml | choco-solver 2019-09-16 |   1.51053  |
# |  2 | XCSP17/AllInterval/AllInterval-m1-s1/AllInterval-035.xml | choco-solver 2019-09-20 |   1.52427  |
# |  3 | XCSP17/AllInterval/AllInterval-m1-s1/AllInterval-035.xml | choco-solver 2019-06-14 |   1.60424  |
# |  4 | XCSP17/AllInterval/AllInterval-m1-s1/AllInterval-035.xml | AbsCon 2019-07-23       |   3.65329  |

# %%
analysis.description_table()
# Out:
#                                                                      analysis
# n_experiment_wares                                                         12
# n_inputs                                                                  300
# n_experiments                                                            3600
# n_missing_xp                                                                0
# n_inconsistent_xp                                                           2
# n_inconsistent_xp_due_to_input                                              0
# more_info_about_variables       <analysis>.data_frame.describe(include='all')

# %%
analysis.pivot_table().head()
# Out:
# experiment_ware                                     AbsCon 2019-07-23  \
# input
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...            3.65329
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...            3.77132
# XCSP17/Bibd/Bibd-sc-open/Bibd-sc-85-085-36-36-1...         2520.04000
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-05-01.xml             2520.10000
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-09-03.xml             2520.11000
#
# experiment_ware                                     BTD 19.07.01  \
# input
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...      0.031203
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...      0.045375
# XCSP17/Bibd/Bibd-sc-open/Bibd-sc-85-085-36-36-1...   2519.910000
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-05-01.xml       2519.890000
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-09-03.xml       2519.770000
#
# experiment_ware                                     Concrete 3.10  \
# input
# ...

# %%
analysis.stat_table()
# Out:
#                                             count     sum    PAR1    PAR2  \
# experiment_ware
# PicatSAT 2019-09-12                           246  127577  127577  192377
# Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)    209  165123  165123  274323
# Fun-sCOP order+GlueMiniSat (2019-06-15)       190  188070  188070  320070
# AbsCon 2019-07-23                             168  182987  182987  341387
# choco-solver 2019-06-14                       168  211446  211446  369846
# Concrete 3.10                                 165  207615  207615  369615
# choco-solver 2019-09-16                       165  210266  210266  372266
# choco-solver 2019-09-20                       165  210316  210316  372316
# Concrete 3.12.3                               156  213476  213476  386276
# choco-solver 2019-09-24                       149  209434  209434  390634
# BTD 19.07.01                                  135  223087  223087  421087
# ...

# %%
analysis.stat_table()
# Out:
#                                             count     sum    PAR1    PAR2  \
# experiment_ware
# PicatSAT 2019-09-12                           246  127577  127577  192377
# Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)    209  165123  165123  274323
# Fun-sCOP order+GlueMiniSat (2019-06-15)       190  188070  188070  320070
# AbsCon 2019-07-23                             168  182987  182987  341387
# choco-solver 2019-06-14                       168  211446  211446  369846
# Concrete 3.10                                 165  207615  207615  369615
# choco-solver 2019-09-16                       165  210266  210266  372266
# choco-solver 2019-09-20                       165  210316  210316  372316
# Concrete 3.12.3                               156  213476  213476  386276
# choco-solver 2019-09-24                       149  209434  209434  390634
# BTD 19.07.01                                  135  223087  223087  421087
# ...

# %%
analysis.contribution_table()
# Out:
#                                             vbew simple  vbew 1s  vbew 10s  \
# experiment_ware
# BTD 19.07.01                                         76       28        11
# cosoco 2                                             55       31        13
# PicatSAT 2019-09-12                                  39       34        29
# Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)           38       38        35
# AbsCon 2019-07-23                                    19       19        15
# Fun-sCOP order+GlueMiniSat (2019-06-15)              16       16        11
# choco-solver 2019-09-24                              14       14         6
# choco-solver 2019-06-14                               7        6         5
# Concrete 3.10                                         6        6         5
# Concrete 3.12.3                                       4        4         4
# choco-solver 2019-09-16                               3        3         2
# ...

# %%
analysis.cactus_plot().head()
# Out:
# experiment_ware  PicatSAT 2019-09-12  \
# 1                           0.005950
# 2                           0.007672
# 3                           0.009281
# 4                           0.010862
# 5                           0.123382
#
# experiment_ware  Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)  \
# 1                                                   2.10905
# 2                                                   4.91833
# 3                                                   4.94725
# 4                                                   5.11415
# 5                                                   5.61449
#
# experiment_ware  Fun-sCOP order+GlueMiniSat (2019-06-15)  AbsCon 2019-07-23  \
# 1                                                2.08807            3.22456
# 2                                                4.88573            3.24719
# 3                                                4.89299            3.24987
# ...

# %%
analysis.cdf_plot().head()
# Out:
#                                                 1         2         3    \
# experiment_ware
# PicatSAT 2019-09-12                         0.00595  0.007672  0.009281
# Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)  2.10905  4.918330  4.947250
# Fun-sCOP order+GlueMiniSat (2019-06-15)     2.08807  4.885730  4.892990
# AbsCon 2019-07-23                           3.22456  3.247190  3.249870
# choco-solver 2019-06-14                     1.24957  1.340830  1.604240
#
#                                                  4         5         6    \
# experiment_ware
# PicatSAT 2019-09-12                         0.010862  0.123382  0.140374
# Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)  5.114150  5.614490  5.652140
# Fun-sCOP order+GlueMiniSat (2019-06-15)     5.167770  5.586440  5.754970
# AbsCon 2019-07-23                           3.361040  3.366080  3.473540
# choco-solver 2019-06-14                     1.684200  1.688560  1.788680
#
# ...

# %%
analysis.scatter_plot('PicatSAT 2019-09-12', 'Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)').head()
# Out:
# experiment_ware                                     Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)  \
# input
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...                                     11.6944
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...                                     14.8833
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-05-01.xml                                         45.0270
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-09-03.xml                                       1689.1700
# XCSP17/Bibd/Bibd-sum-lex/Bibd-sum-09-120-40-03-...                                     38.6328
#
# experiment_ware                                     PicatSAT 2019-09-12
# input
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...             228.6440
# XCSP17/AllInterval/AllInterval-m1-s1/AllInterva...             290.3280
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-05-01.xml                  21.1751
# XCSP17/Bibd/Bibd-sc-stab1/Bibd-sc-25-09-03.xml                 515.6640
# ...
