# %%
# Analysis of the XCSP'19 competition (figure creation)

# %%
from metrics.wallet import *
from autograph.core.enumstyle import FontWeight,Position

# %% [markdown]
# ## Analysis imported!

# %%
analysis = import_analysis_from_file('analysis.csv')

# %%
analysis.data_frame
# Out:
#                                                   input  \
# 0     XCSP17/AllInterval/AllInterval-m1-s1/AllInterv...
# 1     XCSP17/AllInterval/AllInterval-m1-s1/AllInterv...
# 2     XCSP17/AllInterval/AllInterval-m1-s1/AllInterv...
# 3     XCSP17/AllInterval/AllInterval-m1-s1/AllInterv...
# 4     XCSP17/AllInterval/AllInterval-m1-s1/AllInterv...
# ...                                                 ...
# 3895                             XCSP19/hcp/graph48.xml
# 3896                             XCSP19/hcp/graph48.xml
# 3897                             XCSP19/hcp/graph48.xml
# 3898                             XCSP19/hcp/graph48.xml
# 3899                             XCSP19/hcp/graph48.xml
#
#                                  experiment_ware     cpu_time  Checked answer  \
# 0                                       cosoco 2    14.919000             SAT
# 1                              AbsCon 2019-07-23     3.653290             SAT
# ...

# %%
analysis.cactus_plot(
    cumulated=False,
    cactus_col='cpu_time',
    
    title='Cactus-plot',
    x_axis_name='Number of solved inputs',
    y_axis_name='Time',
    
    x_min=50,
    x_max=None,
    y_min=None,
    y_max=None,
    logx=False,
    logy=False,
    
    figsize=(7, 5),
    
    show_marker=True,
    color_map=None,
    style_map=None,
    
    title_font_name='DejaVu Sans',
    title_font_size=12,
    title_font_color='#000000',
    latex_writing=False,
    output="output/cactus.pdf",
    dynamic=False
)
# Out:
# (<Figure size 504x360 with 1 Axes>,
#  <AxesSubplot:title={'center':'Cactus-plot'}, xlabel='Number of solved inputs', ylabel='Time'>)

# %%
analysis.cdf_plot(
    cumulated=False,
    cactus_col='cpu_time',
    
    title='CDF-plot',
    x_axis_name='Time',
    y_axis_name='Number of solved inputs',
    
    x_min=None,
    x_max=None,
    y_min=None,
    y_max=None,
    logx=False,
    logy=False,
    
    figsize=(7, 5),
    
    show_marker=True,
    color_map=None,
    style_map=None,
    
    font_name='DejaVu Sans',
    font_size=12,
    font_color='#000000',
    latex_writing=False,
    output="output/cdf.pdf",
    dynamic=False
)
# Out:
# (<Figure size 504x360 with 1 Axes>,
#  <AxesSubplot:title={'center':'CDF-plot'}, xlabel='Time', ylabel='Number of solved inputs'>)

# %%
analysis.scatter_plot(
            "PicatSAT 2019-09-12",
            "Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)",
            scatter_col="cpu_time",
            title='Scatter-plot',
            figsize=(7, 5),
            color_col=None,
            logx= True,
            logy = True,
            x_min = 0.1,
            y_min = 0.1,
            x_max = None,
            y_max = None,
            title_font_name='DejaVu Sans',
            title_font_size=12,
            title_font_color='#000000',
            title_font_weight=FontWeight.BOLD,
            label_font_name='DejaVu Sans',
            label_font_size=12,
            label_font_color='#000000',
            label_font_weight=FontWeight.NORMAL,
            output="output/scatter.pdf",
            legend_location=Position.RIGHT,
            ncol_legend=1,
            latex_writing= False,
            dynamic = False
    )
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# (<Figure size 504x360 with 1 Axes>,
#  <AxesSubplot:title={'center':'Scatter-plot'}, xlabel='PicatSAT 2019-09-12', ylabel='Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)'>)

# %%
analysis.scatter_plot(
            "PicatSAT 2019-09-12",
            "Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)",
            scatter_col="cpu_time",
            title='Scatter-plot',
            figsize=(7, 5),
            color_col="Checked answer",
            logx= True,
            logy = True,
            x_min = 0.1,
            y_min = 0.1,
            x_max = None,
            y_max = None,
            title_font_name='DejaVu Sans',
            title_font_size=12,
            title_font_color='#000000',
            title_font_weight=FontWeight.BOLD,
            label_font_name='DejaVu Sans',
            label_font_size=12,
            label_font_color='#000000',
            label_font_weight=FontWeight.NORMAL,
            output="output/scattercolorcol.pdf",
            legend_location=Position.RIGHT,
            ncol_legend=1,
            latex_writing= False,
            dynamic = False
    )
# Out:
# (<Figure size 504x360 with 1 Axes>,
#  <AxesSubplot:title={'center':'Scatter-plot'}, xlabel='PicatSAT 2019-09-12', ylabel='Fun-sCOP hybrid+CryptoMiniSat (2019-06-15)'>)

# %%
analysis.box_plot(output="output/box.pdf",log=True,title="Box-plots",title_font_weight=FontWeight.BOLD)
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:title={'center':'Box-plots'}>)
