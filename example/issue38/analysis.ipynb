# %%
from metrics.wallet import *

# %%
analysis = Analysis(input_file='campaign/config/metrics_scalpel.yml')

# %%
analysis.get_cactus_plot()

# %%
analysis.campaign_df.data_frame
# Out:
#     experiment_ware                                input  \
# 0               CHS             PeacableArmies-m2-15_c18
# 1               CHS             GolombRuler-a3v18-12_c18
# 2               CHS        GraphColoring-qg-order100_c18
# 3               CHS            Rlfap-ext-scen-06-opt_c18
# 4               CHS           SumColoring-dsjc-250-9_c18
# 5               CHS                      Bacp-m1-08a_c18
# 6               CHS         GraphColoring-qg-order40_c18
# 7               CHS                Rlfap-scen-09-opt_c18
# 8               CHS             GolombRuler-a3v18-15_c18
# 9               CHS           Rlfap-ext-graph-07-opt_c18
# 10              CHS             SteelMillSlab-m1-3-2_c18
# 11              CHS                 Bacp-m2-10a-nodv_c18
# 12              CHS       SteelMillSlab-m2s-mini-3_0_c18
# 13              CHS                NurseRostering-20_c18
# 14              CHS                    Pb-garden-4x4_c18
# ...
